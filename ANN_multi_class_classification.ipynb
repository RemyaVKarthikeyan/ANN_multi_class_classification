# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
cardio_data = pd.read_csv('Cardiotocographic.csv')

# %%
cardio_data.head()
# Out:
#    BPM       APC  FMPS      UCPS      DLPS  SDPS  PDPS  ASTV  MSTV  ALTV  \
# 0  120  0.000000   0.0  0.000000  0.000000   0.0   0.0    73   0.5    43
# 1  132  0.006380   0.0  0.006380  0.003190   0.0   0.0    17   2.1     0
# 2  133  0.003322   0.0  0.008306  0.003322   0.0   0.0    16   2.1     0
# 3  134  0.002561   0.0  0.007682  0.002561   0.0   0.0    16   2.4     0
# 4  132  0.006515   0.0  0.008143  0.000000   0.0   0.0    16   2.4     0
#
#    MLTV  Width  Min  Max  NSP
# 0   2.4     64   62  126    2
# 1  10.4    130   68  198    1
# 2  13.4    130   68  198    1
# 3  23.0    117   53  170    1
# 4  19.9    117   53  170    1

# %%
cardio_data.tail()
# Out:
#       BPM       APC      FMPS      UCPS  DLPS  SDPS  PDPS  ASTV  MSTV  ALTV  \
# 2121  140  0.000000  0.000000  0.007426   0.0   0.0   0.0    79   0.2    25
# 2122  140  0.000775  0.000000  0.006971   0.0   0.0   0.0    78   0.4    22
# 2123  140  0.000980  0.000000  0.006863   0.0   0.0   0.0    79   0.4    20
# 2124  140  0.000679  0.000000  0.006110   0.0   0.0   0.0    78   0.4    27
# 2125  142  0.001616  0.001616  0.008078   0.0   0.0   0.0    74   0.4    36
#
#       MLTV  Width  Min  Max  NSP
# 2121   7.2     40  137  177    2
# 2122   7.1     66  103  169    2
# 2123   6.1     67  103  170    2
# 2124   7.0     66  103  169    2
# 2125   5.0     42  117  159    1

# %%
cardio_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   BPM     2126 non-null   int64
#  1   APC     2126 non-null   float64
#  2   FMPS    2126 non-null   float64
#  3   UCPS    2126 non-null   float64
#  4   DLPS    2126 non-null   float64
#  5   SDPS    2126 non-null   float64
#  6   PDPS    2126 non-null   float64
#  7   ASTV    2126 non-null   int64
#  8   MSTV    2126 non-null   float64
#  9   ALTV    2126 non-null   int64
#  10  MLTV    2126 non-null   float64
#  11  Width   2126 non-null   int64
#  12  Min     2126 non-null   int64
#  13  Max     2126 non-null   int64
#  14  NSP     2126 non-null   int64
# dtypes: float64(8), int64(7)
# memory usage: 249.3 KB

# %%
cardio_data.describe()
# Out:
#                BPM          APC         FMPS         UCPS         DLPS  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.303857     0.003170     0.009474     0.004357     0.001885
# std       9.840844     0.003860     0.046670     0.002940     0.002962
# min     106.000000     0.000000     0.000000     0.000000     0.000000
# 25%     126.000000     0.000000     0.000000     0.001876     0.000000
# 50%     133.000000     0.001630     0.000000     0.004482     0.000000
# 75%     140.000000     0.005631     0.002512     0.006525     0.003264
# max     160.000000     0.019284     0.480634     0.014925     0.015385
#
#               SDPS         PDPS         ASTV         MSTV        ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.00000
# mean      0.000004     0.000157    46.990122     1.332785     9.84666
# std       0.000063     0.000580    17.192814     0.883241    18.39688
# min       0.000000     0.000000    12.000000     0.200000     0.00000
# 25%       0.000000     0.000000    32.000000     0.700000     0.00000
# 50%       0.000000     0.000000    49.000000     1.200000     0.00000
# 75%       0.000000     0.000000    61.000000     1.700000    11.00000
# max       0.001353     0.005348    87.000000     7.000000    91.00000
#
#               MLTV        Width          Min          Max          NSP
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      8.187629    70.445908    93.579492   164.025400     1.304327
# std       5.628247    38.955693    29.560212    17.944183     0.614377
# min       0.000000     3.000000    50.000000   122.000000     1.000000
# 25%       4.600000    37.000000    67.000000   152.000000     1.000000
# 50%       7.400000    67.500000    93.000000   162.000000     1.000000
# 75%      10.800000   100.000000   120.000000   174.000000     1.000000
# max      50.700000   180.000000   159.000000   238.000000     3.000000

# %%
cardio_data.shape
# Out:
# (2126, 15)

# %%
cardio_data['NSP'].value_counts()
# Out:
# 1    1655
# 2     295
# 3     176
# Name: NSP, dtype: int64

# %%
sns.countplot(cardio_data,x='NSP')
# Out:
# <Axes: xlabel='NSP', ylabel='count'>

# %%
X = cardio_data.drop('NSP',axis=1)
y = cardio_data['NSP'] -1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify=y, random_state=0)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(9,activation='relu',input_shape=(14,)))
model.add(tf.keras.layers.Dense(3,activation='softmax'))

# %%
model.compile(optimizer='adam',
loss='sparse_categorical_crossentropy', metrics='accuracy')

# %%
15
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 9)                 135
#
#  dense_3 (Dense)             (None, 3)                 30
#
# =================================================================
# Total params: 165 (660.00 Byte)
# Trainable params: 165 (660.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
class_weights = { 0:1, 1:6.5, 2:9.4}
history = model.fit(X_train, y_train, batch_size = 32, epochs= 100,verbose=2, class_weight=class_weights,validation_split=0.2)
# Out:
# Epoch 1/100
# 43/43 - 5s - loss: 4.5161 - accuracy: 0.4301 - val_loss: 1.0990 - val_accuracy: 0.5676 - 5s/epoch - 117ms/step
# Epoch 2/100
# 43/43 - 0s - loss: 3.7010 - accuracy: 0.5537 - val_loss: 0.9375 - val_accuracy: 0.6176 - 225ms/epoch - 5ms/step
# Epoch 3/100
# 43/43 - 0s - loss: 3.0761 - accuracy: 0.6037 - val_loss: 0.8467 - val_accuracy: 0.6441 - 213ms/epoch - 5ms/step
# Epoch 4/100
# 43/43 - 0s - loss: 2.6346 - accuracy: 0.6257 - val_loss: 0.7910 - val_accuracy: 0.6588 - 231ms/epoch - 5ms/step
# Epoch 5/100
# 43/43 - 0s - loss: 2.3295 - accuracy: 0.6618 - val_loss: 0.7486 - val_accuracy: 0.6706 - 211ms/epoch - 5ms/step
# Epoch 6/100
# 43/43 - 0s - loss: 2.1169 - accuracy: 0.6824 - val_loss: 0.7157 - val_accuracy: 0.6735 - 248ms/epoch - 6ms/step
# Epoch 7/100
# 43/43 - 0s - loss: 1.9647 - accuracy: 0.6904 - val_loss: 0.6884 - val_accuracy: 0.7029 - 204ms/epoch - 5ms/step
# Epoch 8/100
# 43/43 - 0s - loss: 1.8371 - accuracy: 0.7110 - val_loss: 0.6621 - val_accuracy: 0.7294 - 219ms/epoch - 5ms/step
# Epoch 9/100
# 43/43 - 0s - loss: 1.7293 - accuracy: 0.7338 - val_loss: 0.6362 - val_accuracy: 0.7353 - 216ms/epoch - 5ms/step
# Epoch 10/100
# 43/43 - 0s - loss: 1.6358 - accuracy: 0.7426 - val_loss: 0.6158 - val_accuracy: 0.7559 - 245ms/epoch - 6ms/step
# Epoch 11/100
# 43/43 - 0s - loss: 1.5555 - accuracy: 0.7551 - val_loss: 0.5921 - val_accuracy: 0.7765 - 237ms/epoch - 6ms/step
# Epoch 12/100
# 43/43 - 0s - loss: 1.4888 - accuracy: 0.7632 - val_loss: 0.5746 - val_accuracy: 0.7794 - 138ms/epoch - 3ms/step
# Epoch 13/100
# 43/43 - 0s - loss: 1.4296 - accuracy: 0.7706 - val_loss: 0.5569 - val_accuracy: 0.7853 - 192ms/epoch - 4ms/step
# Epoch 14/100
# 43/43 - 0s - loss: 1.3776 - accuracy: 0.7699 - val_loss: 0.5462 - val_accuracy: 0.7882 - 182ms/epoch - 4ms/step
# Epoch 15/100
# 43/43 - 0s - loss: 1.3292 - accuracy: 0.7779 - val_loss: 0.5319 - val_accuracy: 0.7882 - 146ms/epoch - 3ms/step
# Epoch 16/100
# 43/43 - 0s - loss: 1.2931 - accuracy: 0.7890 - val_loss: 0.5190 - val_accuracy: 0.7941 - 165ms/epoch - 4ms/step
# Epoch 17/100
# 43/43 - 0s - loss: 1.2577 - accuracy: 0.7934 - val_loss: 0.5101 - val_accuracy: 0.8029 - 137ms/epoch - 3ms/step
# Epoch 18/100
# 43/43 - 0s - loss: 1.2231 - accuracy: 0.7941 - val_loss: 0.5029 - val_accuracy: 0.8029 - 190ms/epoch - 4ms/step
# Epoch 19/100
# 43/43 - 0s - loss: 1.1977 - accuracy: 0.7919 - val_loss: 0.4916 - val_accuracy: 0.8088 - 148ms/epoch - 3ms/step
# Epoch 20/100
# 43/43 - 0s - loss: 1.1739 - accuracy: 0.7978 - val_loss: 0.4809 - val_accuracy: 0.8118 - 185ms/epoch - 4ms/step
# Epoch 21/100
# 43/43 - 0s - loss: 1.1511 - accuracy: 0.8037 - val_loss: 0.4757 - val_accuracy: 0.8147 - 148ms/epoch - 3ms/step
# Epoch 22/100
# 43/43 - 0s - loss: 1.1307 - accuracy: 0.8059 - val_loss: 0.4656 - val_accuracy: 0.8176 - 192ms/epoch - 4ms/step
# Epoch 23/100
# 43/43 - 0s - loss: 1.1164 - accuracy: 0.8110 - val_loss: 0.4586 - val_accuracy: 0.8147 - 185ms/epoch - 4ms/step
# Epoch 24/100
# 43/43 - 0s - loss: 1.1012 - accuracy: 0.8147 - val_loss: 0.4541 - val_accuracy: 0.8176 - 143ms/epoch - 3ms/step
# Epoch 25/100
# 43/43 - 0s - loss: 1.0889 - accuracy: 0.8176 - val_loss: 0.4506 - val_accuracy: 0.8176 - 140ms/epoch - 3ms/step
# Epoch 26/100
# 43/43 - 0s - loss: 1.0700 - accuracy: 0.8199 - val_loss: 0.4462 - val_accuracy: 0.8265 - 140ms/epoch - 3ms/step
# Epoch 27/100
# 43/43 - 0s - loss: 1.0596 - accuracy: 0.8221 - val_loss: 0.4404 - val_accuracy: 0.8235 - 140ms/epoch - 3ms/step
# Epoch 28/100
# 43/43 - 0s - loss: 1.0486 - accuracy: 0.8243 - val_loss: 0.4347 - val_accuracy: 0.8235 - 181ms/epoch - 4ms/step
# Epoch 29/100
# 43/43 - 0s - loss: 1.0383 - accuracy: 0.8257 - val_loss: 0.4331 - val_accuracy: 0.8265 - 147ms/epoch - 3ms/step
# Epoch 30/100
# 43/43 - 0s - loss: 1.0287 - accuracy: 0.8272 - val_loss: 0.4253 - val_accuracy: 0.8265 - 146ms/epoch - 3ms/step
# Epoch 31/100
# 43/43 - 0s - loss: 1.0248 - accuracy: 0.8316 - val_loss: 0.4244 - val_accuracy: 0.8265 - 145ms/epoch - 3ms/step
# Epoch 32/100
# 43/43 - 0s - loss: 1.0110 - accuracy: 0.8287 - val_loss: 0.4216 - val_accuracy: 0.8324 - 143ms/epoch - 3ms/step
# Epoch 33/100
# 43/43 - 0s - loss: 1.0031 - accuracy: 0.8309 - val_loss: 0.4185 - val_accuracy: 0.8294 - 144ms/epoch - 3ms/step
# Epoch 34/100
# 43/43 - 0s - loss: 0.9970 - accuracy: 0.8294 - val_loss: 0.4150 - val_accuracy: 0.8265 - 134ms/epoch - 3ms/step
# Epoch 35/100
# 43/43 - 0s - loss: 0.9919 - accuracy: 0.8331 - val_loss: 0.4120 - val_accuracy: 0.8294 - 150ms/epoch - 3ms/step
# Epoch 36/100
# 43/43 - 0s - loss: 0.9843 - accuracy: 0.8301 - val_loss: 0.4161 - val_accuracy: 0.8294 - 140ms/epoch - 3ms/step
# Epoch 37/100
# 43/43 - 0s - loss: 0.9769 - accuracy: 0.8294 - val_loss: 0.4106 - val_accuracy: 0.8353 - 144ms/epoch - 3ms/step
# Epoch 38/100
# 43/43 - 0s - loss: 0.9706 - accuracy: 0.8353 - val_loss: 0.4084 - val_accuracy: 0.8294 - 144ms/epoch - 3ms/step
# Epoch 39/100
# 43/43 - 0s - loss: 0.9642 - accuracy: 0.8368 - val_loss: 0.4038 - val_accuracy: 0.8324 - 146ms/epoch - 3ms/step
# Epoch 40/100
# 43/43 - 0s - loss: 0.9605 - accuracy: 0.8382 - val_loss: 0.3997 - val_accuracy: 0.8324 - 146ms/epoch - 3ms/step
# Epoch 41/100
# 43/43 - 0s - loss: 0.9525 - accuracy: 0.8382 - val_loss: 0.4030 - val_accuracy: 0.8324 - 138ms/epoch - 3ms/step
# Epoch 42/100
# 43/43 - 0s - loss: 0.9467 - accuracy: 0.8382 - val_loss: 0.3998 - val_accuracy: 0.8324 - 153ms/epoch - 4ms/step
# Epoch 43/100
# 43/43 - 0s - loss: 0.9438 - accuracy: 0.8397 - val_loss: 0.3973 - val_accuracy: 0.8412 - 143ms/epoch - 3ms/step
# Epoch 44/100
# 43/43 - 0s - loss: 0.9379 - accuracy: 0.8434 - val_loss: 0.3959 - val_accuracy: 0.8353 - 142ms/epoch - 3ms/step
# Epoch 45/100
# 43/43 - 0s - loss: 0.9332 - accuracy: 0.8412 - val_loss: 0.3946 - val_accuracy: 0.8382 - 137ms/epoch - 3ms/step
# Epoch 46/100
# 43/43 - 0s - loss: 0.9305 - accuracy: 0.8404 - val_loss: 0.3955 - val_accuracy: 0.8382 - 155ms/epoch - 4ms/step
# Epoch 47/100
# 43/43 - 0s - loss: 0.9235 - accuracy: 0.8390 - val_loss: 0.3948 - val_accuracy: 0.8382 - 144ms/epoch - 3ms/step
# Epoch 48/100
# 43/43 - 0s - loss: 0.9225 - accuracy: 0.8419 - val_loss: 0.3937 - val_accuracy: 0.8353 - 144ms/epoch - 3ms/step
# Epoch 49/100
# 43/43 - 0s - loss: 0.9144 - accuracy: 0.8456 - val_loss: 0.3895 - val_accuracy: 0.8353 - 144ms/epoch - 3ms/step
# Epoch 50/100
# 43/43 - 0s - loss: 0.9113 - accuracy: 0.8434 - val_loss: 0.3889 - val_accuracy: 0.8353 - 145ms/epoch - 3ms/step
# Epoch 51/100
# 43/43 - 0s - loss: 0.9088 - accuracy: 0.8426 - val_loss: 0.3910 - val_accuracy: 0.8353 - 148ms/epoch - 3ms/step
# Epoch 52/100
# 43/43 - 0s - loss: 0.9063 - accuracy: 0.8441 - val_loss: 0.3864 - val_accuracy: 0.8382 - 141ms/epoch - 3ms/step
# Epoch 53/100
# 43/43 - 0s - loss: 0.9010 - accuracy: 0.8426 - val_loss: 0.3872 - val_accuracy: 0.8382 - 181ms/epoch - 4ms/step
# Epoch 54/100
# 43/43 - 0s - loss: 0.8974 - accuracy: 0.8463 - val_loss: 0.3845 - val_accuracy: 0.8412 - 184ms/epoch - 4ms/step
# Epoch 55/100
# 43/43 - 0s - loss: 0.8916 - accuracy: 0.8456 - val_loss: 0.3840 - val_accuracy: 0.8412 - 146ms/epoch - 3ms/step
# Epoch 56/100
# 43/43 - 0s - loss: 0.8908 - accuracy: 0.8449 - val_loss: 0.3827 - val_accuracy: 0.8412 - 145ms/epoch - 3ms/step
# Epoch 57/100
# 43/43 - 0s - loss: 0.8894 - accuracy: 0.8449 - val_loss: 0.3818 - val_accuracy: 0.8441 - 148ms/epoch - 3ms/step
# Epoch 58/100
# 43/43 - 0s - loss: 0.8842 - accuracy: 0.8449 - val_loss: 0.3812 - val_accuracy: 0.8471 - 182ms/epoch - 4ms/step
# Epoch 59/100
# 43/43 - 0s - loss: 0.8838 - accuracy: 0.8449 - val_loss: 0.3826 - val_accuracy: 0.8441 - 196ms/epoch - 5ms/step
# Epoch 60/100
# 43/43 - 0s - loss: 0.8814 - accuracy: 0.8434 - val_loss: 0.3803 - val_accuracy: 0.8471 - 149ms/epoch - 3ms/step
# Epoch 61/100
# 43/43 - 0s - loss: 0.8763 - accuracy: 0.8449 - val_loss: 0.3791 - val_accuracy: 0.8500 - 186ms/epoch - 4ms/step
# Epoch 62/100
# 43/43 - 0s - loss: 0.8737 - accuracy: 0.8434 - val_loss: 0.3803 - val_accuracy: 0.8412 - 136ms/epoch - 3ms/step
# Epoch 63/100
# 43/43 - 0s - loss: 0.8702 - accuracy: 0.8449 - val_loss: 0.3783 - val_accuracy: 0.8529 - 141ms/epoch - 3ms/step
# Epoch 64/100
# 43/43 - 0s - loss: 0.8686 - accuracy: 0.8463 - val_loss: 0.3774 - val_accuracy: 0.8559 - 141ms/epoch - 3ms/step
# Epoch 65/100
# 43/43 - 0s - loss: 0.8678 - accuracy: 0.8478 - val_loss: 0.3737 - val_accuracy: 0.8529 - 151ms/epoch - 4ms/step
# Epoch 66/100
# 43/43 - 0s - loss: 0.8644 - accuracy: 0.8456 - val_loss: 0.3760 - val_accuracy: 0.8529 - 149ms/epoch - 3ms/step
# Epoch 67/100
# 43/43 - 0s - loss: 0.8607 - accuracy: 0.8456 - val_loss: 0.3746 - val_accuracy: 0.8500 - 148ms/epoch - 3ms/step
# Epoch 68/100
# 43/43 - 0s - loss: 0.8604 - accuracy: 0.8456 - val_loss: 0.3781 - val_accuracy: 0.8500 - 156ms/epoch - 4ms/step
# Epoch 69/100
# 43/43 - 0s - loss: 0.8576 - accuracy: 0.8456 - val_loss: 0.3749 - val_accuracy: 0.8588 - 145ms/epoch - 3ms/step
# Epoch 70/100
# 43/43 - 0s - loss: 0.8551 - accuracy: 0.8478 - val_loss: 0.3753 - val_accuracy: 0.8500 - 142ms/epoch - 3ms/step
# Epoch 71/100
# 43/43 - 0s - loss: 0.8516 - accuracy: 0.8493 - val_loss: 0.3732 - val_accuracy: 0.8529 - 145ms/epoch - 3ms/step
# Epoch 72/100
# 43/43 - 0s - loss: 0.8519 - accuracy: 0.8478 - val_loss: 0.3709 - val_accuracy: 0.8559 - 144ms/epoch - 3ms/step
# Epoch 73/100
# 43/43 - 0s - loss: 0.8471 - accuracy: 0.8463 - val_loss: 0.3724 - val_accuracy: 0.8471 - 137ms/epoch - 3ms/step
# Epoch 74/100
# 43/43 - 0s - loss: 0.8475 - accuracy: 0.8493 - val_loss: 0.3755 - val_accuracy: 0.8529 - 192ms/epoch - 4ms/step
# Epoch 75/100
# 43/43 - 0s - loss: 0.8448 - accuracy: 0.8456 - val_loss: 0.3749 - val_accuracy: 0.8529 - 194ms/epoch - 5ms/step
# Epoch 76/100
# 43/43 - 0s - loss: 0.8394 - accuracy: 0.8485 - val_loss: 0.3730 - val_accuracy: 0.8500 - 226ms/epoch - 5ms/step
# Epoch 77/100
# 43/43 - 0s - loss: 0.8409 - accuracy: 0.8485 - val_loss: 0.3714 - val_accuracy: 0.8529 - 234ms/epoch - 5ms/step
# Epoch 78/100
# 43/43 - 0s - loss: 0.8369 - accuracy: 0.8478 - val_loss: 0.3723 - val_accuracy: 0.8529 - 203ms/epoch - 5ms/step
# Epoch 79/100
# 43/43 - 0s - loss: 0.8408 - accuracy: 0.8493 - val_loss: 0.3702 - val_accuracy: 0.8588 - 238ms/epoch - 6ms/step
# Epoch 80/100
# 43/43 - 0s - loss: 0.8331 - accuracy: 0.8529 - val_loss: 0.3703 - val_accuracy: 0.8588 - 188ms/epoch - 4ms/step
# Epoch 81/100
# 43/43 - 0s - loss: 0.8312 - accuracy: 0.8537 - val_loss: 0.3698 - val_accuracy: 0.8588 - 227ms/epoch - 5ms/step
# Epoch 82/100
# 43/43 - 0s - loss: 0.8300 - accuracy: 0.8507 - val_loss: 0.3712 - val_accuracy: 0.8559 - 226ms/epoch - 5ms/step
# Epoch 83/100
# 43/43 - 0s - loss: 0.8283 - accuracy: 0.8537 - val_loss: 0.3700 - val_accuracy: 0.8559 - 232ms/epoch - 5ms/step
# Epoch 84/100
# 43/43 - 0s - loss: 0.8293 - accuracy: 0.8522 - val_loss: 0.3699 - val_accuracy: 0.8529 - 211ms/epoch - 5ms/step
# Epoch 85/100
# 43/43 - 0s - loss: 0.8264 - accuracy: 0.8559 - val_loss: 0.3690 - val_accuracy: 0.8588 - 138ms/epoch - 3ms/step
# Epoch 86/100
# 43/43 - 0s - loss: 0.8240 - accuracy: 0.8529 - val_loss: 0.3681 - val_accuracy: 0.8559 - 140ms/epoch - 3ms/step
# Epoch 87/100
# 43/43 - 0s - loss: 0.8213 - accuracy: 0.8544 - val_loss: 0.3705 - val_accuracy: 0.8529 - 138ms/epoch - 3ms/step
# Epoch 88/100
# 43/43 - 0s - loss: 0.8223 - accuracy: 0.8551 - val_loss: 0.3696 - val_accuracy: 0.8529 - 178ms/epoch - 4ms/step
# Epoch 89/100
# 43/43 - 0s - loss: 0.8193 - accuracy: 0.8529 - val_loss: 0.3701 - val_accuracy: 0.8559 - 142ms/epoch - 3ms/step
# Epoch 90/100
# 43/43 - 0s - loss: 0.8165 - accuracy: 0.8544 - val_loss: 0.3678 - val_accuracy: 0.8529 - 155ms/epoch - 4ms/step
# Epoch 91/100
# 43/43 - 0s - loss: 0.8154 - accuracy: 0.8551 - val_loss: 0.3659 - val_accuracy: 0.8588 - 139ms/epoch - 3ms/step
# Epoch 92/100
# 43/43 - 0s - loss: 0.8159 - accuracy: 0.8522 - val_loss: 0.3690 - val_accuracy: 0.8559 - 133ms/epoch - 3ms/step
# Epoch 93/100
# 43/43 - 0s - loss: 0.8124 - accuracy: 0.8544 - val_loss: 0.3676 - val_accuracy: 0.8500 - 141ms/epoch - 3ms/step
# Epoch 94/100
# 43/43 - 0s - loss: 0.8124 - accuracy: 0.8522 - val_loss: 0.3661 - val_accuracy: 0.8588 - 178ms/epoch - 4ms/step
# Epoch 95/100
# 43/43 - 0s - loss: 0.8092 - accuracy: 0.8566 - val_loss: 0.3678 - val_accuracy: 0.8529 - 137ms/epoch - 3ms/step
# Epoch 96/100
# 43/43 - 0s - loss: 0.8095 - accuracy: 0.8551 - val_loss: 0.3675 - val_accuracy: 0.8559 - 145ms/epoch - 3ms/step
# Epoch 97/100
# 43/43 - 0s - loss: 0.8085 - accuracy: 0.8515 - val_loss: 0.3681 - val_accuracy: 0.8588 - 154ms/epoch - 4ms/step
# Epoch 98/100
# 43/43 - 0s - loss: 0.8084 - accuracy: 0.8566 - val_loss: 0.3682 - val_accuracy: 0.8559 - 138ms/epoch - 3ms/step
# Epoch 99/100
# 43/43 - 0s - loss: 0.8062 - accuracy: 0.8588 - val_loss: 0.3663 - val_accuracy: 0.8588 - 141ms/epoch - 3ms/step
# Epoch 100/100
# 43/43 - 0s - loss: 0.8038 - accuracy: 0.8544 - val_loss: 0.3691 - val_accuracy: 0.8529 - 150ms/epoch - 3ms/step

# %%
accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
plt.plot(accuracy, label='Training Set Accuracy')
plt.plot(validation_accuracy, label='Validation Set Accuracy')
plt.ylabel('Accuracy')
plt.ylim([0.4,1])
plt.title('Training and Validation Accuracy Across Epochs')
plt.legend()

# %%
loss = history.history['loss']
validation_loss = history.history['val_loss']
plt.plot(loss, label='Training Set Loss')
plt.plot(validation_loss, label='Validation Set Loss')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs')
plt.legend()

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# Out:
# 14/14 [==============================] - 0s 2ms/step

# %%
confusion_matrix = confusion_matrix(y_test,y_pred)
ax = sns.heatmap(confusion_matrix, cmap='flare',annot=True, fmt='d')
plt.xlabel("Predicted Class",fontsize=12)
plt.ylabel("True Class",fontsize=12)
plt.title("Confusion Matrix",fontsize=12)
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.33      0.44       332
#            1       0.00      0.00      0.00        59
#            2       0.07      0.51      0.12        35
#
#     accuracy                           0.30       426
#    macro avg       0.24      0.28      0.19       426
# weighted avg       0.52      0.30      0.35       426
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
